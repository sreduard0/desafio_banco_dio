# %% [markdown]
# Instalando dependencias

# %%
# !pip install flask
# !pip install flask-ngrok

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn

# %% [markdown]
# Codigo python

# %%
import random
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn

app = FastAPI()

names = nomes = [
    "Sophia",
    "Liam",
    "Olivia",
    "Noah",
    "Emma",
    "Jackson",
    "Ava",
    "Aiden",
    "Isabella",
    "Lucas",
    "Mia",
    "Caden",
    "Aria",
    "Grayson",
    "Riley",
    "Mason",
    "Layla",
    "Elijah",
    "Zoe",
    "Logan",
    "Charlotte",
    "Oliver",
    "Amelia",
    "Carter",
    "Harper",
    "Daniel",
    "Evelyn",
    "Jacob",
    "Lily",
    "Michael",
    "Addison",
    "Benjamin",
    "Aubrey",
    "Emily",
    "Matthew",
    "Lillian",
    "James",
    "Natalie",
    "Jack",
    "Hannah",
    "William",
    "Avery",
    "Alexander",
    "Sofia",
    "Sebastian",
    "Chloe",
    "Joseph",
    "Ella",
    "Levi",
    "Grace",
    "Jayden",
    "Victoria",
    "Owen",
    "Elizabeth",
    "Dylan",
    "Penelope",
    "Wyatt",
    "Scarlett",
    "Luke",
    "Madison",
    "Gabriel",
    "Aurora",
    "Anthony",
    "Paisley",
    "Isaac",
    "Ariana",
    "Julian",
    "Brooklyn",
    "Christopher",
    "Bella",
    "Joshua",
    "Luna",
    "Andrew",
    "Savannah",
    "David",
    "Maya",
    "John",
    "Skylar",
    "Samuel",
    "Nora",
    "Joseph",
    "Camila",
    "Johnathan",
    "Hazel",
    "Nathan",
    "Abigail",
    "Ryan",
    "Ellie",
    "Christian",
    "Stella",
    "Caleb",
    "Piper",
    "Hunter",
    "Liliana",
    "Eli",
    "Leah",
    "Isaiah",
    "Samantha",
    "Henry",
    "Violet",
    "Jonathan",
    "Everly",
    "Landon",
    "Caroline",
    "Aaron",
    "Eleanor"
]


@app.get('/api/nomes')
async def random_name():
    random_name = random.choice(names)
    return {'name': random_name}

if __name__ == '__main__':
    ngrok_tunnel = ngrok.connect(8000)

print('URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-07-05T05:07:47+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# URL: https://a426-34-106-205-25.ngrok.io
# INFO:     Started server process [341]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [341]
